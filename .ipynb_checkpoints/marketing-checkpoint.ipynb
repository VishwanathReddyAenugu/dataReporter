# %%
import pandas as pd
import matplotlib
import seaborn as sns

import DataReporter
# %run -i DataReporter.py

# %%
df = pd.read_csv("data.csv")
pd.set_option("display.max_rows",None)
pd.set_option("display.max_columns",None)

# %%
report = Report(df) 
report.eda()
# Out:
#  Size of the data set (2240, 28)
#
#  Number of Unique values per column
#
#
#
# Num of unique values in ID  :  2240
# column  ID  has high variance
#
#
# Year_Birth  :  59
# [1970 1961 1958 1967 1989 1954 1947 1979 1959 1981 1969 1977 1960 1966
#  1976 1965 1956 1975 1971 1986 1972 1974 1990 1987 1984 1968 1955 1983
#  1973 1978 1952 1962 1964 1982 1963 1957 1980 1945 1949 1948 1953 1946
#  1985 1992 1944 1951 1988 1950 1994 1993 1991 1893 1996 1995 1899 1943
#  1941 1940 1900]
#
#
# Education  :  5
# ['Graduation' 'PhD' '2n Cycle' 'Master' 'Basic']
#
#
# Marital_Status  :  8
# ['Divorced' 'Single' 'Married' 'Together' 'Widow' 'YOLO' 'Alone' 'Absurd']
#
#
# Num of unique values in  Income   :  1975
# column   Income   has high variance
#
#
# Kidhome  :  3
# [0 1 2]
#
#
# Teenhome  :  3
# [0 1 2]
#
#
# Num of unique values in Dt_Customer  :  663
# column  Dt_Customer  has high variance
#
#
# Num of unique values in Recency  :  100
# column  Recency  has high variance
#
#
# Num of unique values in MntWines  :  776
# column  MntWines  has high variance
#
#
# Num of unique values in MntFruits  :  158
# column  MntFruits  has high variance
#
#
# Num of unique values in MntMeatProducts  :  558
# column  MntMeatProducts  has high variance
#
#
# Num of unique values in MntFishProducts  :  182
# column  MntFishProducts  has high variance
#
#
# Num of unique values in MntSweetProducts  :  177
# column  MntSweetProducts  has high variance
#
#
# Num of unique values in MntGoldProds  :  213
# column  MntGoldProds  has high variance
#
#
# NumDealsPurchases  :  15
# [ 1  2  3  0  4 12  7  5  6 11  9  8 10 15 13]
#
#
# NumWebPurchases  :  15
# [ 4  7  3  1 10  2  6  5 25  8  9  0 11 27 23]
#
#
# NumCatalogPurchases  :  14
# [ 4  3  2  0  1  7 10  6  8  5  9 11 28 22]
#
#
# NumStorePurchases  :  14
# [ 6  7  5  2  3  9 10  0  8  4 13 12  1 11]
#
#
# NumWebVisitsMonth  :  16
# [ 1  5  2  7  6  4  8  3  9  0 17 13 10 14 19 20]
#
#
# AcceptedCmp3  :  2
# [0 1]
#
#
# AcceptedCmp4  :  2
# [0 1]
#
#
# AcceptedCmp5  :  2
# [0 1]
#
#
# AcceptedCmp1  :  2
# [0 1]
#
#
# AcceptedCmp2  :  2
# [0 1]
#
#
# Response  :  2
# [1 0]
#
#
# Complain  :  2
# [0 1]
#
#
# Country  :  8
# ['SP' 'CA' 'US' 'AUS' 'GER' 'IND' 'SA' 'ME']

# %%
report.missing()
